# %% [markdown]
# # Overview
#
# We're now switching focus away from the Network Science (for a little bit), beginning to think about _Natural Language Processing_ instead. In other words, today will be all about teaching your computer to "understand" text. This ties in nicely with our work on Reddit, because subbmisions and comments often contain text. We've looked at the network so far - now, let's see if we can include the text. Today is about
#
# * Installing the _natural language toolkit_ (NLTK) package and learning the basics of how it works (Chapter 1)
# * Figuring out how to make NLTK to work with other types of text (Chapter 2).

# %% [markdown]
# > **_Video Lecture_**. [Intro to Natural Language processing](https://www.youtube.com/watch?v=Ph0EHmFT3n4). Today is all about working with NLTK, so not much lecturing - we will start with a perspective on text analysis by Sune (you will hear him talking about Wikipedia data here and there. Everything he sais applies to Reddit data as well!)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("Ph0EHmFT3n4",width=800, height=450)

# %% [markdown]
# # Installing and the basics
#
# > _Reading_
# > The reading for today is Natural Language Processing with Python (NLPP) Chapter 1, Sections 1.1, 1.2, 1.3\. [It's free online](http://www.nltk.org/book/).

# %% [markdown]
# > *Exercises*: NLPP Chapter 1\.
# >
# > * First, install `nltk` if it isn't installed already (there are some tips below that I recommend checking out before doing installing)
# > * Second, work through chapter 1. The book is set up as a kind of tutorial with lots of examples for you to work through. I recommend you read the text with an open IPython Notebook and type out the examples that you see. ***It becomes much more fun if you to add a few variations and see what happens***. Some of those examples might very well be due as assignments (see below the install tips), so those ones should definitely be in a `notebook`.

# %% [markdown]
# ### NLTK Install tips
#
# Check to see if `nltk` is installed on your system by typing `import nltk` in a `notebook`. If it's not already installed, install it as part of _Anaconda_ by typing
#
#      conda install nltk
#
# at the command prompt. If you don't have them, you can download the various corpora using a command-line version of the downloader that runs in Python notebooks: In the iPython notebook, run the code
#
#      import nltk
#      nltk.download()
#
# Now you can hit `d` to download, then type "book" to fetch the collection needed today's `nltk` session. Now that everything is up and running, let's get to the actual exercises.

# %% [markdown]
# > *Exercises: NLPP Chapter 1 (the stuff that might be due in an upcoming assignment).
# >
# > The following exercises from Chapter 1 are what might be due in an assignment later on.
# >
# > * Try out the `concordance` method, using another text and a word of your own choosing.
# > * Also try out the `similar` and `common_context` methods for a few of your own examples.
# > * Create your own version of a dispersion plot ("your own version" means another text and different word).
# > * Explain in your own words what aspect of language _lexical diversity_ describes.
# > * Create frequency distributions for `text2`, including the cumulative frequency plot for the 75 most common words.
# > * What is a bigram? How does it relate to `collocations`. Explain in your own words.
# > * Work through ex 2-12 in NLPP's section 1.8\.
# > * Work through exercise 15, 17, 19, 22, 23, 26, 27, 28 in section 1.8\.

# %%
# !pip install nltk
import nltk
# nltk.download() # will pop up in seperate window
# nltk.data.path = []
nltk.data.path.append("C:/Users/lukas/OneDrive/Dokumenter/DTU/6. Sem/02467 - Social Informatik/comsocsci2021/lectures/Data/nltk_data")
# nltk.data.path.append("C:\Users\lukas\OneDrive\Dokumenter\DTU\6. Sem\02467 - Social Informatik\comsocsci2021\lectures\Data\nltk_data")
nltk.data.path
bold = '\033[1m'
underline = '\033[4m'
end = '\033[0m'

# %% [markdown]
# ## Stuff from chapter 1

# %%
# import
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# text objects
display(text1)
display(text2)
# Out:
# <Text: Moby Dick by Herman Melville 1851>
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
# searching text
# sjhow occurences
word = "monstrous"
print(bold, underline, f"Occurences of word {word}", end)
display(text1.concordance(word))

# similar words
print(bold, underline, f"Similar words of {word}", end)
display(text1.similar(word))

#common words
word2 = "very"
print(bold, underline, f"Common words of {word} and {word2}", end)
display(text2.common_contexts([word, word2]))

# dispersion plot
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

# generate text
print(bold, underline, f"Generated text from text3", end)
print(text3.generate())
# Out:
#   Occurences of word monstrous
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u
# None
# ...

# %% [markdown]
# ## Counting vocabulary

# %%
print(bold, f"Length of text 3:", end)
print("\t", len(text3))

print(bold, "Words in alphabetical order:", end)
print("\t",sorted(set(text3))[:20])

print(bold, "Unique words:", end)
print("\t",len(set(text3)))

print(bold, "Distinct word percentage", end)
print("\t", len(set(text3)) / len(text3))

print(bold, "Occurences of word smote", end)
print("\t", text3.count("smote"))

print(bold, "Percentage of text that is the word 'a':", end)
print("\t", 100 * text4.count('a') / len(text4))

def lexical_diversity(text):
    return len(set(text)) / len(text)

def percentage(count, total):
    return 100 * count / total

print(bold, "Lexical diversity of text3:", end)
print("\t",lexical_diversity(text3))

print(bold, "Lexical diversity of text5:", end)
print("\t",lexical_diversity(text5))

print(bold, "Percetnage of word 'a' in text4:", end)
print("\t",percentage(text4.count('a'), len(text4)))
# Out:
#  Length of text 3:
# 	 44764
#  Words in alphabetical order:
# 	 ['!', "'", '(', ')', ',', ',)', '.', '.)', ':', ';', ';)', '?', '?)', 'A', 'Abel', 'Abelmizraim', 'Abidah', 'Abide', 'Abimael', 'Abimelech']
#  Unique words:
# 	 2789
#  Distinct word percentage
# 	 0.06230453042623537
#  Occurences of word smote
# 	 5
#  Percentage of text that is the word 'a':
# 	 1.457973123627309
#  Lexical diversity of text3:
# 	 0.06230453042623537
#  Lexical diversity of text5:
# 	 0.13477005109975562
#  Percetnage of word 'a' in text4:
# 	 1.457973123627309

# %% [markdown]
# ## Texts as lists of words

# %% [markdown]
# ## Simple statistics

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done',
         'more', 'is', 'said', 'than', 'done']
tokens = set(saying)
tokens = sorted(tokens)
tokens[-2:]
# Out:
# ['said', 'than']

# %%
# frequency distributions
fdist1 = FreqDist(text1) 
print("fdist1 = ", fdist1)

print(bold, "Most common words:", end)
print(fdist1.most_common(50))

print(bold, "Occurences of word whale", end, "\n\t", fdist1['whale'])
# Out:
# fdist1 =  <FreqDist with 19317 samples and 260819 outcomes>
#  Most common words:
# [(',', 18713), ('the', 13721), ('.', 6862), ('of', 6536), ('and', 6024), ('a', 4569), ('to', 4542), (';', 4072), ('in', 3916), ('that', 2982), ("'", 2684), ('-', 2552), ('his', 2459), ('it', 2209), ('I', 2124), ('s', 1739), ('is', 1695), ('he', 1661), ('with', 1659), ('was', 1632), ('as', 1620), ('"', 1478), ('all', 1462), ('for', 1414), ('this', 1280), ('!', 1269), ('at', 1231), ('by', 1137), ('but', 1113), ('not', 1103), ('--', 1070), ('him', 1058), ('from', 1052), ('be', 1030), ('on', 1005), ('so', 918), ('whale', 906), ('one', 889), ('you', 841), ('had', 767), ('have', 760), ('there', 715), ('But', 705), ('or', 697), ('were', 680), ('now', 646), ('which', 640), ('?', 637), ('me', 627), ('like', 624)]
#  Occurences of word whale
# 	 906

# %%
# fine grained selection of words
V = set(text1)
long_words = [w for w in V if len(w) > 15]
print(bold,"Sorted long words:", end, "\n\t", sorted(long_words))

fdist5 = FreqDist(text5)
print(bold, "Words longer than 7 characters and with more than 7 occurences:", end, "\n\t", sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7))
# Out:
#  Sorted long words:
# 	 ['CIRCUMNAVIGATION', 'Physiognomically', 'apprehensiveness', 'cannibalistically', 'characteristically', 'circumnavigating', 'circumnavigation', 'circumnavigations', 'comprehensiveness', 'hermaphroditical', 'indiscriminately', 'indispensableness', 'irresistibleness', 'physiognomically', 'preternaturalness', 'responsibilities', 'simultaneousness', 'subterraneousness', 'supernaturalness', 'superstitiousness', 'uncomfortableness', 'uncompromisedness', 'undiscriminating', 'uninterpenetratingly']
#  Words longer than 7 characters and with more than 7 occurences:
# 	 ['#14-19teens', '#talkcity_adults', '((((((((((', '........', 'Question', 'actually', 'anything', 'computer', 'cute.-ass', 'everyone', 'football', 'innocent', 'listening', 'remember', 'seriously', 'something', 'together', 'tomorrow', 'watching']

# %%
# collocations and bigrams
print(bold, "Some bigrams:", end, "\n\t", list(bigrams(['more', 'is', 'said', 'than', 'done'])))

print(bold, "Collocations from text 4:", end)
print("\t", text4.collocations())

print(bold, "Collocations from text 8:", end)
print("\t", text8.collocations())
# Out:
#  Some bigrams:
# 	 [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]
#  Collocations from text 4:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; God
# bless; Chief Justice; Old World; Almighty God; Fellow citizens; Chief
# Magistrate; every citizen; one another; fellow Americans; Indian
# tribes; public debt; foreign nations
# 	 None
#  Collocations from text 8:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build
# 	 None

# %%
# counting other things
print(bold, "Length of words in text 1", end)
print("\t", [len(w) for w in text1[:10]])

fdist = FreqDist(len(w) for w in text1)
print(bold, "Dictionary with count of word lengths", end)
display(fdist)

fdist = FreqDist(len(w) for w in text1)
print(bold, "Most common length", end)
print("\t", fdist.most_common())

print(bold, "Most common word length", end)
print("\t", fdist.max())

print(bold, "Number of 3 letter words", end)
print("\t", fdist[3])

print(bold, "Freqeuncy of 3 letter words", end)
print("\t", fdist.freq(3))
# Out:
#  Length of words in text 1
# 	 [1, 4, 4, 2, 6, 8, 4, 1, 9, 1]
#  Dictionary with count of word lengths
# FreqDist({3: 50223, 1: 47933, 4: 42345, 2: 38513, 5: 26597, 6: 17111, 7: 14399, 8: 9966, 9: 6428, 10: 3528, ...})
#  Most common length
# 	 [(3, 50223), (1, 47933), (4, 42345), (2, 38513), (5, 26597), (6, 17111), (7, 14399), (8, 9966), (9, 6428), (10, 3528), (11, 1873), (12, 1053), (13, 567), (14, 177), (15, 70), (16, 22), (17, 12), (18, 1), (20, 1)]
#  Most common word length
# 	 3
#  Number of 3 letter words
# 	 50223
#  Freqeuncy of 3 letter words
# 	 0.19255882431878046

# %% [markdown]
# ### Exercise 2
# Given an alphabet of 26 letters, there are 26 to the power 10, or 26 ** 10, ten-letter strings we can form. That works out to 141167095653376. How many hundred-letter strings are possible?
# > - $26^{100}$ as we have 26 options for each of the 100 places in the string

# %% [markdown]
# ### Exercise 3
# The Python multiplication operation can be applied to lists. What happens when you type ['Monty', 'Python'] * 20, or 3 * sent1?
# > - the lsits will be duplicated 20 and 3 times

# %%
# ["Monty", "Python"]*20
3*sent1
# Out:
# ['Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Call',
#  'me',
#  'Ishmael',
#  '.',
#  'Call',
#  'me',
#  'Ishmael',
#  '.']

# %% [markdown]
# ### Exercise 4
# Review 1 on computing with language. How many words are there in text2? How many distinct words are there?

# %%
print(f"There are {len(text2)} words in text2")
print(f"There are {len(set(text2))} distinct words in text2")
# Out:
# There are 141576 words in text2
# There are 6833 distinct words in text2

# %% [markdown]
# ### Exercise 5
# Compare the lexical diversity scores for humor and romance fiction in 1.1. Which genre is more lexically diverse?
# <div id="bg">
#   <img src="attachment:image.png" alt="" width = 500>
# </div>
#
# >- it is seen that humor is more lexical diverse as it has the highest score, meaning a larger part of the words used are distinct

# %% [markdown]
# ### Exercise 6
# Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?
# >- The two females (top) are mentioned more often than the two males (bottom)
# >- it is difficult to indety the couples as the females are mentioned very often

# %%
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %% [markdown]
# ### Exercise 7
# Find the collocations in text5.

# %%
print(bold, underline, "Collocations (words metioned together) in text 5", end)
text5.collocations()
# Out:
#   Collocations (words metioned together) in text 5
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# ### Exercise 8
# Consider the following Python expression: len(set(text4)). State the purpose of this expression. Describe the two steps involved in performing this computation.
# >- set finds all the unoique words
# >- len counts the number of words
# >- put together the number of unique words are found

# %% [markdown]
# ### Exercise 9
#  Review 2 on lists and strings.
# > - Define a string and assign it to a variable, e.g., my_string = 'My String' (but put something more interesting in the string). Print the contents of this variable in two ways, first by simply typing the variable name and pressing enter, then by using the print statement. <br>
# > - Try adding the string to itself using my_string + my_string, or multiplying it by a number, e.g., my_string * 3. Notice that the strings are joined together without any spaces. How could you fix this?

# %%
my_str = "The couples live together at Delaford and remain in close \
touch with their mother and younger sister at Barton Cottage."
display(my_str)
print(my_str, "\n")
print(my_str*2, "\n")
print((my_str + " ")*2) # quick fix to add space between strings, will cause an off by one error in the end of the string though
# Out:
# 'The couples live together at Delaford and remain in close touch with their mother and younger sister at Barton Cottage.'
# The couples live together at Delaford and remain in close touch with their mother and younger sister at Barton Cottage.
#
# The couples live together at Delaford and remain in close touch with their mother and younger sister at Barton Cottage.The couples live together at Delaford and remain in close touch with their mother and younger sister at Barton Cottage.
#
# The couples live together at Delaford and remain in close touch with their mother and younger sister at Barton Cottage. The couples live together at Delaford and remain in close touch with their mother and younger sister at Barton Cottage.

# %% [markdown]
# ### Exercise 10
# Define a variable my_sent to be a list of words, using the syntax my_sent = ["My", "sent"] (but with your own words, or a favorite saying).
# > - Use ' '.join(my_sent) to convert this into a string.
# > - Use split() to split the string back into the list form you had to start with.

# %%
my_sent = ["Flip", "flop", "floppity", "wop"]
my_sent_joined = " ".join(my_sent)
my_sent_split = my_sent_joined.split()
display(my_sent_joined)
display(my_sent_split)
# Out:
# 'Flip flop floppity wop'
# ['Flip', 'flop', 'floppity', 'wop']

# %% [markdown]
# ### Exercise 11
# Define several variables containing lists of words, e.g., phrase1, phrase2, and so on. Join them together in various combinations (using the plus operator) to form whole sentences. What is the relationship between len(phrase1 + phrase2) and len(phrase1) + len(phrase2)?
# >- the legnths are equal, are they are lists and not strings

# %%
s1 = ["Define", "several", "variables", "containing", "lists", "of", "words"]
s2 = ["Join", "them", "together", "in", "various", "combinations", "using", "the", "plus", "operator", "to", "form", "whole", "sentences"]
s3 = ["What", "is", "the", "relationship", "between"]

print(f"Len(s1+s2) = {len(s1+s2)}")
print(f"Len(s1+s3) = {len(s1+s3)}")
print(f"Len(s2+s3) = {len(s2+s3)}")
print(f"Len(s1+s2+s3) = {len(s1+s2+s3)}")
print(f"Len(s1)+len(s2) = {len(s1)+len(s2)}")
print(f"Len(s1)+len(s3) = {len(s1)+len(s3)}")
print(f"Len(s2)+len(s3) = {len(s2)+len(s3)}")
print(f"Len(s1)+len(s2)+len(s3) = {len(s1)+len(s2)+len(s3)}")
# Out:
# Len(s1+s2) = 21
# Len(s1+s3) = 12
# Len(s2+s3) = 19
# Len(s1+s2+s3) = 26
# Len(s1)+len(s2) = 21
# Len(s1)+len(s3) = 12
# Len(s2)+len(s3) = 19
# Len(s1)+len(s2)+len(s3) = 26

# %% [markdown]
# ### Exercise 12
# Consider the following two expressions, which have the same value. Which one will typically be more relevant in NLP? Why?
# > - "Monty Python"[6:12]
# > - ["Monty", "Python"][1]
#
# >- Will typically use the second, as we tokenize all the words

# %% [markdown]
# ### Exercise 15
# Review the discussion of conditionals in 4. Find all words in the Chat Corpus (text5) starting with the letter b. Show them in alphabetical order.

# %%
sorted(set([w for w in text5 if w.lower().startswith("b")]))
# Out:
# ['B',
#  'BAAAAALLLLLLLLIIIIIIINNNNNNNNNNN',
#  'BE',
#  'BIG',
#  'BLONDES',
#  'BOOTS',
#  'BOOTY',
#  'BOY',
#  'BUT',
#  'BUt',
#  'BYE',
#  'Back',
#  'Barbieee',
#  'Barometer',
#  'Beach',
#  'Because',
#  'Been',
#  'Ben',
#  'Benjamin',
#  'Better',
#  'Bible',
#  'Biiiiiitch',
#  'Biographys',
#  'Birdgang',
#  'Bloooooooood',
#  'Bloooooooooood',
#  'Bloooooooooooood',
#  'Bone',
#  'Bonus',
#  'Books',
#  'Boone',
#  'Booyah',
#  'Borat',
#  'Born',
#  'Box',
#  'Boyz',
#  'Break',
#  'Breaking',
#  'Broken',
#  'Bud',
#  'Burger',
#  'But',
#  'Bwhaha',
#  'Bye',
#  'b',
#  'b-day',
#  'b/c',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babes',
#  'babi',
#  'babies',
#  'babiess',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'backatchya',
#  'backfrontsidewaysandallaroundtheworld',
#  'backroom',
#  'backup',
#  'bacl',
#  'bad',
#  'bag',
#  'bagel',
#  'bagels',
#  'bahahahaa',
#  'bak',
#  'baked',
#  'balad',
#  'balance',
# ...

# %% [markdown]
# ### Exercise 17
# Use text9.index() to find the index of the word sunset. You'll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
idx_sunset = text9.index("sunset")
print("Index of sunset = ", idx_sunset)
print(bold, "First go at entire sentence: ",end)
print("\t", " ".join(text9[idx_sunset-20:idx_sunset+20])) # notice first word is THE and last is second sunset

print(bold, "Final go at entire sentence: ",end)
print("\t", " ".join(text9[idx_sunset-8:idx_sunset+15])) # without period it is 14
# Out:
# Index of sunset =  629
#  First go at entire sentence:
# 	 K . C . CHAPTER I THE TWO POETS OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset . It was built of a
#  Final go at entire sentence:
# 	 THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %% [markdown]
# ### Exercise 19
# What is the difference between the following two lines? Which one will give a larger value? Will this be the case for other texts?
# >- \>\>\> sorted(set(w.lower() for w in text1))
# >- \>\>\> sorted(w.lower() for w in set(text1))
#
# >- in the first the word is set to lower before finding unique values, thus Boy and boy are mapped to the same value. In the second these will both appear as boy and boy in the sorted list
# >- the second has the largest value as the case of the first letter is not ignored
# >- this will apply to all texts, the first statement can never have more words than the second

# %%
display(len(sorted(set(w.lower() for w in text1))))
display(len(sorted(w.lower() for w in set(text1))))
# Out:
# 17231
# 19317

# %% [markdown]
# ### Exercise 22
# Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %%
fdist5 = FreqDist(text5)
sorted(list({i:j for i,j in fdist5.items() if len(i) == 4}.keys()))
# Out:
# ['!!!!',
#  '!!!.',
#  '!...',
#  '!???',
#  '"...',
#  '####',
#  '((((',
#  '))))',
#  ',,,,',
#  '.. .',
#  '....',
#  '.op.',
#  '1.98',
#  '1.99',
#  '100%',
#  '10th',
#  '1200',
#  '1299',
#  '18ST',
#  '1900',
#  '1930',
#  '1980',
#  '1985',
#  '1996',
#  '1cos',
#  '2006',
#  '2:55',
#  '2DAY',
#  '2Pac',
#  '39.3',
#  '3:45',
#  '4.20',
#  '45.5',
#  '4:03',
#  '64.8',
#  '6:38',
#  '6:41',
#  '6:51',
#  '6:53',
#  '7:45',
#  '9.53',
#  '98.5',
#  '98.6',
#  '9:10',
#  ':o *',
#  '; ..',
#  '<---',
#  "<3's",
#  '<333',
#  '<<<<',
#  '<~~~',
#  '>:->',
#  '?!?!',
#  '??!!',
#  '????',
#  'AKDT',
#  'AKST',
#  'AWAY',
#  'Ahhh',
#  'Away',
#  'Awww',
#  'Back',
#  'Been',
#  'Bone',
#  'Born',
#  'Boyz',
#  'CALI',
#  'CAPS',
#  'CHAT',
#  'COME',
#  'Came',
#  'Care',
#  'Chat',
#  'Chop',
#  'City',
#  'Come',
#  'Cool',
#  'Ctrl',
#  'Cute',
#  'DAMN',
#  'DING',
#  'DOES',
#  'DONT',
#  'Damn',
#  'Dang',
#  'Dawn',
#  'Days',
#  'Deep',
#  'Does',
#  'Dood',
# ...

# %% [markdown]
# ### Exercise 23
# Review the discussion of looping with conditions in 4. Use a combination of for and if statements to loop over the words of the movie script for Monty Python and the Holy Grail (text6) and print all the uppercase words, one per line.

# %%
[print(w) for w in text6 if w[0].isupper()]
# Out:
# SCENE
# KING
# ARTHUR
# Whoa
# SOLDIER
# Halt
# Who
# ARTHUR
# It
# I
# Arthur
# Uther
# Pendragon
# Camelot
# King
# Britons
# Saxons
# England
# SOLDIER
# Pull
# ARTHUR
# I
# Patsy
# We
# Camelot
# I
# SOLDIER
# What
# Ridden
# ARTHUR
# Yes
# SOLDIER
# You
# ARTHUR
# What
# SOLDIER
# You
# ARTHUR
# So
# We
# Mercea
# SOLDIER
# Where
# ARTHUR
# We
# SOLDIER
# Found
# In
# Mercea
# The
# ARTHUR
# What
# SOLDIER
# Well
# ARTHUR
# The
# SOLDIER
# Are
# ARTHUR
# Not
# They
# SOLDIER
# What
# A
# ARTHUR
# It
# SOLDIER
# It
# It
# A
# ARTHUR
# Well
# Will
# Arthur
# Court
# Camelot
# SOLDIER
# Listen
# In
# ARTHUR
# Please
# SOLDIER
# Am
# I
# ARTHUR
# I
# SOLDIER
# It
# African
# SOLDIER
# Oh
# African
# European
# That
# SOLDIER
# Oh
# I
# ARTHUR
# Will
# Camelot
# SOLDIER
# But
# African
# SOLDIER
# Oh
# SOLDIER
# So
# SOLDIER
# Wait
# Supposing
# SOLDIER
# No
# SOLDIER
# Well
# They
# SOLDIER
# What
# SOLDIER
# Well
# SCENE
# CART
# MASTER
# Bring
# Bring
# Bring
# Bring
# Bring
# ...

# %% [markdown]
# ### Exercise 26
# What does the following Python code do? sum(len(w) for w in text1) Can you use it to work out the average word length of a text?
# >- counts the number of letters in the text

# %%
print("The average word length in text1 is: ", sum(len(w) for w in text1)/len(text1))
# Out:
# The average word length in text1 is:  3.830411128023649

# %% [markdown]
# ### Exercise 27
# Define a function called vocab_size(text) that has a single parameter for the text, and which returns the vocabulary size of the text.

# %%
def vocab_size(text):
    return len(set([t.lower() for t in text])) # list comprehension to make sure boy and Boy are the same
vocab_size(text1)
# Out:
# 17231

# %% [markdown]
# ### Exercise 28
#  Define a function percent(word, text) that calculates how often a given word occurs in a text, and expresses the result as a percentage.

# %%
def percent(word, text):
    return FreqDist(text)[word]/len(text)*100

percent("a", text1)
# Out:
# 1.7517895552087845

# %% [markdown]
# # Working with NLTK and other types of text
#
# Chapter 2 in NLPP1e is all about getting access to nicely curated texts that you can find built into NLTK.
# >
# > Reading: NLPP Chapter 2.1 - 2.4\.
# >

# %% [markdown]
# > *Exercises*: NLPP Chapter 2\.
# >
# > * Solve exercise 4, 8, 11, 15, 16, 17, 18 in NLPP1e, section 2.8\. As always, I recommend you write up your solutions nicely in a `notebook`.

# %% [markdown]
# ### Exercise 4
# Read in the texts of the State of the Union addresses, using the state_union corpus reader. Count occurrences of men, women, and people in each document. What has happened to the usage of these words over time?

# %%
import nltk
nltk.data.path.append("C:/Users/lukas/OneDrive\Dokumenter/DTU/6. Sem/02467 - Social Informatik/comsocsci2021/lectures/Data/nltk_data")
from nltk.corpus import state_union

# list(state_union)
len(state_union.words())
# Out:
# 399822

# %% [markdown]
# ### Exercise 8
# Define a conditional frequency distribution over the Names corpus that allows you to see which initial letters are more frequent for males vs. females (cf. 4.4).

# %% [markdown]
# ### Exercise 11
# Investigate the table of modal distributions and look for other patterns. Try to explain them in terms of your own impressionistic understanding of the different genres. Can you find other closed classes of words that exhibit significant differences across different genres?

# %% [markdown]
# ### Exercise 15
#  Write a program to find all words that occur at least three times in the Brown Corpus.

# %% [markdown]
# ### Exercise 16
# Write a program to generate a table of lexical diversity scores (i.e. token/type ratios), as we saw in 1.1. Include the full set of Brown Corpus genres (nltk.corpus.brown.categories()). Which genre has the lowest diversity (greatest number of tokens per type)? Is this what you would have expected?

# %% [markdown]
# ### Exercise 17
# Write a function that finds the 50 most frequently occurring words of a text that are not stopwords.

# %% [markdown]
# ### Exercise 18
# Write a program to print the 50 most frequent bigrams (pairs of adjacent words) of a text, omitting bigrams that contain stopwords.
